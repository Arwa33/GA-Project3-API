# %%
#Import Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

# %%
Talal_Najat = pd.read_csv('Music.csv')
Talal_Najat.shape
# Out:
# (1249, 16)

# %%
Talal_Najat.head()
# Out:
#    Unnamed: 0    album  track_number                      id           name  \
# 0           0  أحرجتنى             1  48a1eiJrtnJvUbLkZZpCBZ        أحرجتنى
# 1           1  أحرجتنى             2  7xEoUPYht1B9WRaCt622N8   فى خاطرى شىء
# 2           2  أحرجتنى             3  1fOoW6LJsXDwNkTlvwTlkq     خطوة عزيزة
# 3           3  أحرجتنى             4  2wdH8EWrDsntvBYmno1xVm  يا ساهر الليل
# 4           4  أحرجتنى             5  5sGCytl6ilk066Mx7BEE7f    موسيقى طلال
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:48a1eiJrtnJvUbLkZZpCBZ         0.697         0.549   0.305
# 1  spotify:track:7xEoUPYht1B9WRaCt622N8         0.608         0.438   0.290
# 2  spotify:track:1fOoW6LJsXDwNkTlvwTlkq         0.674         0.539   0.247
# 3  spotify:track:2wdH8EWrDsntvBYmno1xVm         0.830         0.274   0.183
# 4  spotify:track:5sGCytl6ilk066Mx7BEE7f         0.698         0.411   0.242
#
# ...

# %%
Talal_Najat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 16 columns):
# Unnamed: 0          1249 non-null int64
# album               1249 non-null object
# track_number        1249 non-null int64
# id                  1249 non-null object
# name                1249 non-null object
# uri                 1249 non-null object
# acousticness        1249 non-null float64
# danceability        1249 non-null float64
# energy              1249 non-null float64
# instrumentalness    1249 non-null float64
# liveness            1249 non-null float64
# loudness            1249 non-null float64
# speechiness         1249 non-null float64
# tempo               1249 non-null float64
# valence             1249 non-null float64
# popularity          1249 non-null int64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 156.2+ KB

# %%
Talal_Najat.isnull().sum()
# Out:
# Unnamed: 0          0
# album               0
# track_number        0
# id                  0
# name                0
# uri                 0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# dtype: int64

# %%
Talal_Najat.describe()
# Out:
#         Unnamed: 0  track_number  acousticness  danceability       energy  \
# count  1249.000000   1249.000000   1249.000000   1249.000000  1249.000000
# mean    624.000000      5.860689      0.491928      0.521854     0.587884
# std     360.699552      4.246394      0.303096      0.139065     0.218414
# min       0.000000      1.000000      0.001040      0.131000     0.030500
# 25%     312.000000      3.000000      0.209000      0.410000     0.412000
# 50%     624.000000      5.000000      0.490000      0.537000     0.643000
# 75%     936.000000      8.000000      0.772000      0.628000     0.762000
# max    1248.000000     27.000000      0.995000      0.873000     0.964000
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       1249.000000  1249.000000  1249.000000  1249.000000  1249.000000
# mean           0.018341     0.245187    -8.980773     0.078062   122.061911
# ...

# %%
# Columns
Talal_Najat.columns
# Out:
# Index(['Unnamed: 0', 'album', 'track_number', 'id', 'name', 'uri',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence',
#        'popularity'],
#       dtype='object')

# %%
#Drop column
Talal_Najat.drop(Talal_Najat.columns[[0, 2, 3, 5]], axis = 1, inplace = True)

# %%
Talal_Najat.head()
# Out:
#      album           name  acousticness  danceability  energy  \
# 0  أحرجتنى        أحرجتنى         0.697         0.549   0.305
# 1  أحرجتنى   فى خاطرى شىء         0.608         0.438   0.290
# 2  أحرجتنى     خطوة عزيزة         0.674         0.539   0.247
# 3  أحرجتنى  يا ساهر الليل         0.830         0.274   0.183
# 4  أحرجتنى    موسيقى طلال         0.698         0.411   0.242
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000000     0.108   -14.882       0.0341  144.076    0.629
# 1          0.000852     0.135   -16.633       0.0428  158.635    0.478
# 2          0.000000     0.338   -16.479       0.0339  145.865    0.668
# 3          0.000462     0.116   -18.411       0.0468  181.397    0.362
# 4          0.930000     0.141   -20.123       0.0349  158.730    0.606
#
#    popularity
# 0          20
# 1          10
# 2           9
# 3          11
# 4           9

# %%
Talal_Najat.rename(columns = {'album':'album_name', 'name':'song_name'}, inplace = True)

# %%
Talal_Najat.head(100)
# Out:
#     album_name              song_name  acousticness  danceability  energy  \
# 0      أحرجتنى                أحرجتنى         0.697         0.549   0.305
# 1      أحرجتنى           فى خاطرى شىء         0.608         0.438   0.290
# 2      أحرجتنى             خطوة عزيزة         0.674         0.539   0.247
# 3      أحرجتنى          يا ساهر الليل         0.830         0.274   0.183
# 4      أحرجتنى            موسيقى طلال         0.698         0.411   0.242
# ..         ...                    ...           ...           ...     ...
# 95  حلاوة الحب  حلاوة الحب تسجيل حفلة         0.927         0.328   0.310
# 96  حلاوة الحب           سارقين النوم         0.917         0.356   0.317
# 97    شكل تانى               شكل تانى         0.952         0.398   0.284
# 98    شكل تانى             القريب منك         0.770         0.439   0.340
# 99    شكل تانى             عال اليادى         0.606         0.396   0.480
#
#     instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# ...

# %%
Talal_Najat.reset_index(drop=True)
# Out:
#      album_name      song_name  acousticness  danceability  energy  \
# 0       أحرجتنى        أحرجتنى         0.697         0.549   0.305
# 1       أحرجتنى   فى خاطرى شىء         0.608         0.438   0.290
# 2       أحرجتنى     خطوة عزيزة         0.674         0.539   0.247
# 3       أحرجتنى  يا ساهر الليل         0.830         0.274   0.183
# 4       أحرجتنى    موسيقى طلال         0.698         0.411   0.242
# ...         ...            ...           ...           ...     ...
# 1244  آن الأوان      آن الاوان         0.831         0.307   0.424
# 1245  آن الأوان     زمان الصبا         0.819         0.616   0.506
# 1246  آن الأوان      شفايف عنب         0.830         0.509   0.572
# 1247  آن الأوان     مرات عديدة         0.766         0.364   0.517
# 1248  آن الأوان     مغير القمر         0.860         0.384   0.422
#
#       instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0             0.000000    0.1080   -14.882       0.0341  144.076    0.629
# ...

# %%
Talal_Najat.columns
# Out:
# Index(['album_name', 'song_name', 'acousticness', 'danceability', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity'],
#       dtype='object')

# %% [markdown]
# # Correlation Between Variables

# %% [markdown]
# Valence and Energy

# %%
fig, ax = plt.subplots()
style.use('seaborn')
Talal_Najat.plot(kind='scatter',x='valence', y='energy',ax = ax , colormap = 'Accent_r' ,title="Valence x Energy")
ax.set_xlabel("Valence")
plt.show()

# %% [markdown]
# Valence and Danceability

# %%
fig, ax = plt.subplots()
style.use('seaborn')
Talal_Najat.plot(kind='scatter',x='valence', y='danceability',ax = ax , colormap = 'Accent_r' ,title="Valence x Danceability")
ax.set_xlabel("Valence")
plt.show()

# %%
fig, ax = plt.subplots()
style.use('seaborn')
Talal_Najat.plot(kind='scatter',x='popularity', y='danceability',ax = ax , colormap = 'Accent_r' ,title="Popularity x Energy")
ax.set_xlabel("Popularity")
plt.show()

# %%
fig, ax = plt.subplots()
style.use('seaborn')
Talal_Najat.plot(kind='scatter',x='acousticness', y='liveness',ax = ax , colormap = 'Accent_r' ,title="acousticness x liveness")
ax.set_xlabel("acousticness")
plt.show()

# %%
sns.heatmap(Talal_Najat.corr())

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(50,50))
ax = sns.barplot(x='liveness', y='album_name', data=Talal_Najat)
ax.set_xlabel('liveness')
# Out:
# Text(0.5, 0, 'liveness')

# %%
TalalNajat = Talal_Najat['album_name'].unique()
print (sorted(TalalNajat))
# Out:
# ["'Anasheed Fadel", "A'azz El Naz", 'Agrab Al Nass', 'Ahla W Ahla', 'Al Hob Al Jadid', 'Ala Albal', 'Allah Karim', 'Ana Habibi', 'Awedouny', 'Baada Aal Bal', 'Balean Aleha Elhob', 'Ban Sahi Al Tarf', "Banadeek Ta'ala", 'Beirut Concert - Live Rare Recordings', 'Best Of Rashed Pt.2', 'Canada Concert-Live Rare Recording', 'Dastour', 'Dul Mush Habayeb', 'Eid Al Farah', 'El Hawa Sultan Rare Recordings', 'El Hob Shatter- Rare Recording', 'El Khataya Aashar', 'El Lilady (Tonight)', 'El Shok Wal Hob', 'Ensan Aktar', 'Enta Al Hawa', 'Esmaany 2015', 'Gaswah', 'Hafla 2004', 'Haflet Dubai 2014, Vol. 1 & 2 (Live)', 'Haflet Jeddah', 'Haflet Taj Mahal', 'Inta Gheirhom', 'Kalam Ennas', 'Kalamak Ya Habibi', 'Kammel Kalamak', 'Kol Hayaty', 'Kuwait Concert - LIVE Rare recording', 'La Tisrig Al Wagt', 'La Warabi', 'Law Wafeet', 'Layali Febrayer 2009', 'Lovely Majeed (Jalsat & Oud)', 'Ma Fi Daii', 'Mashy El Tarek', 'Mawawel (Live Rare Recording)', 'Meaddy El Nas', 'Melyon Khater', 'Mn Asmaa Allah Al Hosn
# ...

# %%
Talal_Najat.loc[Talal_Najat['popularity'].idxmax()]
# Out:
# album_name          تملى معاك
# song_name           تملى معاك
# acousticness            0.121
# danceability            0.623
# energy                  0.781
# instrumentalness     2.77e-05
# liveness                0.101
# loudness               -9.651
# speechiness            0.0373
# tempo                 167.874
# valence                 0.346
# popularity                 53
# Name: 433, dtype: object

# %%
Talal_Najat.loc[Talal_Najat['energy'].idxmax()]
# Out:
# album_name           Banadeek Ta'ala
# song_name           Tagroba Wa Addet
# acousticness                   0.018
# danceability                   0.713
# energy                         0.964
# instrumentalness             0.00185
# liveness                      0.0692
# loudness                      -4.844
# speechiness                   0.0348
# tempo                        131.443
# valence                        0.924
# popularity                        20
# Name: 372, dtype: object

# %%
Talal_Najat.loc[Talal_Najat['danceability'].idxmax()]
# Out:
# album_name          Kammel Kalamak
# song_name           Away Ana A'ref
# acousticness                 0.701
# danceability                 0.873
# energy                       0.515
# instrumentalness          1.96e-05
# liveness                     0.213
# loudness                    -9.891
# speechiness                 0.0418
# tempo                      120.017
# valence                        0.7
# popularity                      16
# Name: 402, dtype: object

# %%
Talal_Najat.loc[Talal_Najat['liveness'].idxmax()]
# Out:
# album_name                   التوبة
# song_name           سواح تسجيل حفلة
# acousticness                  0.916
# danceability                  0.366
# energy                        0.411
# instrumentalness                  0
# liveness                      0.983
# loudness                     -10.71
# speechiness                   0.046
# tempo                       133.553
# valence                       0.357
# popularity                       25
# Name: 510, dtype: object

# %%
Talal_Najat.to_csv('Talal_Najat.csv',index=False)

# %%
df = pd.read_csv('Talal_Najat.csv')
df.head()
# Out:
#   album_name      song_name  acousticness  danceability  energy  \
# 0    أحرجتنى        أحرجتنى         0.697         0.549   0.305
# 1    أحرجتنى   فى خاطرى شىء         0.608         0.438   0.290
# 2    أحرجتنى     خطوة عزيزة         0.674         0.539   0.247
# 3    أحرجتنى  يا ساهر الليل         0.830         0.274   0.183
# 4    أحرجتنى    موسيقى طلال         0.698         0.411   0.242
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.000000     0.108   -14.882       0.0341  144.076    0.629
# 1          0.000852     0.135   -16.633       0.0428  158.635    0.478
# 2          0.000000     0.338   -16.479       0.0339  145.865    0.668
# 3          0.000462     0.116   -18.411       0.0468  181.397    0.362
# 4          0.930000     0.141   -20.123       0.0349  158.730    0.606
#
#    popularity
# 0          20
# 1          10
# 2           9
# 3          11
# 4           9

# %%
df.shape
# Out:
# (1249, 12)

# %%
# take a look at descriptive statistics summary
df.describe().transpose().sort_values(by=[ 'mean','std','min','max'], ascending=False)
# Out:
#                    count        mean        std       min      25%  \
# tempo             1249.0  122.061911  30.713745  56.30500  94.8080
# popularity        1249.0   10.045637  10.962874   0.00000   2.0000
# valence           1249.0    0.606145   0.211564   0.03900   0.4490
# energy            1249.0    0.587884   0.218414   0.03050   0.4120
# danceability      1249.0    0.521854   0.139065   0.13100   0.4100
# acousticness      1249.0    0.491928   0.303096   0.00104   0.2090
# liveness          1249.0    0.245187   0.221562   0.01320   0.0925
# speechiness       1249.0    0.078062   0.060839   0.02440   0.0391
# instrumentalness  1249.0    0.018341   0.101789   0.00000   0.0000
# loudness          1249.0   -8.980773   3.990097 -22.67400 -11.0820
#
#                          50%         75%      max
# tempo             123.270000  144.764000  208.066
# popularity          5.000000   16.000000   53.000
# valence             0.628000    0.769000    0.974
# ...

# %%
corr = df.corr()
corr['valence'].sort_values(ascending = False)
# Out:
# valence             1.000000
# danceability        0.554577
# energy              0.538040
# loudness            0.147652
# speechiness         0.145880
# popularity          0.114307
# tempo               0.109506
# instrumentalness   -0.001698
# liveness           -0.116111
# acousticness       -0.434191
# Name: valence, dtype: float64

# %%
X=df.iloc[0:,3:10]
X.head()
y=df.iloc[0:,-2]
y.head()
# Out:
# 0    0.629
# 1    0.478
# 2    0.668
# 3    0.362
# 4    0.606
# Name: valence, dtype: float64

# %%
X.shape
# Out:
# (1249, 7)

# %%
X.tail()
# Out:
#       danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 1244         0.307   0.424          0.000000    0.3360    -9.622       0.0429
# 1245         0.616   0.506          0.000000    0.1340    -8.559       0.0532
# 1246         0.509   0.572          0.000008    0.1440    -8.527       0.0430
# 1247         0.364   0.517          0.000000    0.2760    -8.529       0.0445
# 1248         0.384   0.422          0.000000    0.0925    -9.903       0.0435
#
#         tempo
# 1244  159.164
# 1245  123.827
# 1246   97.608
# 1247  186.396
# 1248  109.712

# %%
y.shape
# Out:
# (1249,)

# %%
y.head()
# Out:
# 0    0.629
# 1    0.478
# 2    0.668
# 3    0.362
# 4    0.606
# Name: valence, dtype: float64

# %%
from sklearn.linear_model import ElasticNet, Lasso,  Ridge, LinearRegression, RidgeCV
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import ElasticNet, Lasso,  Ridge, LinearRegression, RidgeCV
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.dummy import DummyRegressor

# %%
# Partition the dataset in train + validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
# Transform your dataset with Robust Scalar to decrease the influence of the outliers
rs = RobustScaler()
X_train_s = rs.fit_transform(X_train)
X_test_s = rs.transform(X_test)

# %%
#Validation function

def rmsle_cv(model):
    rmse= np.sqrt(-cross_val_score(model, X_train_s, y_train, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

def rmsle_cv_test(model):
    rmse= np.sqrt(-cross_val_score(model, X_test_s, y_test, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

# %%
lm = LinearRegression()
lm.fit(X_train_s, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Get score of train and test
model = lm
score = rmsle_cv(model)
print("\nLinear model train score: {:.4f} ± {:.4f}\n".format(score.mean(), score.std()))
score = rmsle_cv_test(model)
print("\nLinear model Test score: {:.4f} ± {:.4f}\n".format(score.mean(), score.std()))
# Out:
# Linear model train score: 0.1500 ± 0.0098
#
#
# Linear model Test score: 0.1588 ± 0.0053
